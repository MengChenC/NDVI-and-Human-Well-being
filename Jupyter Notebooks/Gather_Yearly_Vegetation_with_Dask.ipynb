# %% [markdown]
# #### Author: MengChen Chung

# %% [markdown]
# ## Spin up cluster

# %%
from dask_yarn import YarnCluster
from dask.distributed import Client

# %%
# Create a cluster where each worker has 1 cores and 4 GiB of memory:
cluster = YarnCluster(environment="/home/hadoop/environment.tar.gz",
                      worker_vcores = 1,
                      worker_memory = "4GiB"
                      )

# Scale cluster out to 8 such workers:
cluster.scale(8)

# Connect to the cluster (before proceeding, you should wait for workers to be registered by the dask scheduler, as below):
client = Client(cluster)

# %%
client

# %% [markdown]
# ## Process geodata

# %%
# import modules
import dask
from dask import delayed
import rioxarray
import geopandas as gpd


def get_average_vegetation(tif_file, shape_file, state_idx):
    # read in tif file
    with rioxarray.open_rasterio(tif_file,
                                 chunks={'band': 1, 'x': 1024, 'y': 1024}) as xds:
        # clip the raster data based on the boundary
        # handle 'MultiPolygon' and 'Polygon' in shape file
        if shape_file.geometry[state_idx] != 'MultiPolygon':
            clipped = xds.rio.clip([shape_file.geometry[state_idx]])
        else:
            clipped = xds.rio.clip(shape_file.geometry[state_idx])
        # stack DataArray to be 1D
        clipped = clipped.squeeze().stack(z=("x", "y"))
        # filter out invalid index (-3000) then calculate the mean
        clipped = clipped[clipped!=-3000].mean()
    return clipped

# %%
# read in shape file
shape_file = gpd.read_file("cb_2018_us_state_500k/cb_2018_us_state_500k.shp")
# filter out non-state in the shape file
state_idx_list = [i for i in range(0, 56) if i not in (13,27,36,37,38,42,44,45)]
# creat NDVI and EVI lists
NDVI_file_list = ['NDVI/MOD13A1.006__500m_16_days_NDVI_doy2018{0:03d}_aid0001.tif'.format(i) for i in range(1,365,16)]
EVI_file_list = ['EVI/MOD13A1.006__500m_16_days_EVI_doy2018{0:03d}_aid0001.tif'.format(i) for i in range(1,365,16)]

# %%
NDVI_dic={} # dictionary for storing each state's avg index
for i, tif_file in enumerate(NDVI_file_list):
    for state_idx in state_idx_list:
        clipped = get_average_vegetation(tif_file, shape_file, state_idx)
        # first time we create keys and values
        # other times we update the dictionary
        if i == 0:
            NDVI_dic[state_idx] = clipped
        else:
            NDVI_dic[state_idx] += clipped
NDVI_dic
# Out:
# {0: Delayed('add-02492bbc1af26bb342703b01ba6621dd'),
#  1: Delayed('add-b2f33e0d1bc0b80a157ab0af26b340d4'),
#  2: Delayed('add-8d0fdea1661775733fee6225941a980b'),
#  3: Delayed('add-43dc0331dbaf91f28980e9d1fdad25c3'),
#  4: Delayed('add-bc731768a1dde4645b97900a06400aae'),
#  5: Delayed('add-ea9bf5271a31772789fead1e0bd8c39c'),
#  6: Delayed('add-b3f5893662c9c0e5099df05e50b5fe8d'),
#  7: Delayed('add-8760d410aae3231d6ac9eface6557f3d'),
#  8: Delayed('add-d455c2850a8a1e0a9b06347f410e3042'),
#  9: Delayed('add-884ef909bfa887440153572edeceb5a2'),
#  10: Delayed('add-ce82bb6d5738821b64e7b314468839ff'),
#  11: Delayed('add-a27e78459c4abd14b4fc07041b2bdebc'),
#  12: Delayed('add-b60775d5f3d47fe151c357676b617fe8'),
#  14: Delayed('add-67f28327c5f35391f40cc45aa8dd4385'),
#  15: Delayed('add-ebba09c8f5a8ffb5caa825930c0b7350'),
#  16: Delayed('add-638e08a21a70c8ff61239119a0dc338e'),
#  17: Delayed('add-02d82c6b13649842afff8d61c5065e18'),
#  18: Delayed('add-d1ea00e96c7f12230e92ecb250fe3b30'),
#  19: Delayed('add-54d8fa1baf4bcc7acb918789d6651849'),
#  20: Delayed('add-48f18f0688e5dba7beb567467f0401dd'),
#  21: Delayed('add-7032f29308445df8289b4de0ad4bc09e'),
#  22: Delayed('add-d633b2a0db108dfa4f176d05403999be'),
#  23: Delayed('add-531f7ecfd3e6ebf74004388d7c35e3a1'),
#  24: Delayed('add-56c5caf4d4985596f298a923386adf92'),
#  25: Delayed('add-b7bde148d88656ae16d5d92192d19182'),
#  26: Delayed('add-62bd2d5841621f811ac31f32d50d579a'),
#  28: Delayed('add-38e8ce4b32b23d4dfa11c2cb523be018'),
#  29: Delayed('add-ae8e7f09eb61a29f94cb9513b30079d4'),
#  30: Delayed('add-a13cb534c6e714d3d029aab58cd0e55e'),
#  31: Delayed('add-e7992e2935437fbd1c9595fa845ea886'),
#  32: Delayed('add-30407817436e2e7c27075cea661ab77b'),
#  33: Delayed('add-e823234041481eb4688d8e82dda16adf'),
#  34: Delayed('add-56f32fbed57f45de8a10e76eb85a5ddd'),
#  35: Delayed('add-790d063cdeb751f3190374881be051ee'),
#  39: Delayed('add-4646568f000a0ada16c3f75f856cf647'),
#  40: Delayed('add-cfd8f65cf2c265cd7b0fc3c33aee968c'),
#  41: Delayed('add-8372ba9837f9365a0c1d833ab61d1c6e'),
#  43: Delayed('add-aca81d8b0acdb387356b4528fd11f6bf'),
#  46: Delayed('add-09411aca593db0c9f06113ee03fd5613'),
#  47: Delayed('add-a80e72df66d11c2c3e29c978583a25f2'),
#  48: Delayed('add-5856a2a5c1e02e8405f8db5051e3551d'),
#  49: Delayed('add-d9ea531ecf4a9ab214c659d7292fa73d'),
#  50: Delayed('add-d36b136e18611f46f4b59b18df8a9a07'),
#  51: Delayed('add-74ed1cd38f974cfdb4da1fe3445641c6'),
#  52: Delayed('add-b9006cac3577f0de7964811c3ca2c720'),
#  53: Delayed('add-4d814d8fa89d3a93bdf1f500becaf8ab'),
#  54: Delayed('add-efb588c4bf41e8c350e136dd0cbaf045'),
#  55: Delayed('add-92ad2bf80d266cf35339ae1576184730')}

# %%
# compute all the values in NDVI_dic and update the dictionary
NDVI_dic = {k: v.compute() for k, v in NDVI_dic.items()}
NDVI_dic
# Out:
# Counter({0: <xarray.DataArray ()>
#          array(154382.25880277)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          1: <xarray.DataArray ()>
#          array(151986.26649021)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          2: <xarray.DataArray ()>
#          array(112027.92206453)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          3: <xarray.DataArray ()>
#          array(152561.5162586)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          4: <xarray.DataArray ()>
#          array(145094.55589142)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          5: <xarray.DataArray ()>
#          array(145832.16930434)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          6: <xarray.DataArray ()>
#          array(112133.0099354)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          7: <xarray.DataArray ()>
#          array(143175.26177255)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          8: <xarray.DataArray ()>
#          array(78674.11830048)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          9: <xarray.DataArray ()>
#          array(144804.87481574)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          10: <xarray.DataArray ()>
#          array(85849.48179708)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          11: <xarray.DataArray ()>
#          array(113882.9162479)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          12: <xarray.DataArray ()>
#          array(57002.97458043)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          14: <xarray.DataArray ()>
#          array(78061.34362901)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          15: <xarray.DataArray ()>
#          array(97714.56305531)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          16: <xarray.DataArray ()>
#          array(87968.52218699)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          17: <xarray.DataArray ()>
#          array(161246.61710508)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          18: <xarray.DataArray ()>
#          array(155313.28876184)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          19: <xarray.DataArray ()>
#          array(136258.67191183)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          20: <xarray.DataArray ()>
#          array(131087.30723881)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          21: <xarray.DataArray ()>
#          array(68816.75243101)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          22: <xarray.DataArray ()>
#          array(51297.92597413)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          23: <xarray.DataArray ()>
#          array(148918.66723185)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          24: <xarray.DataArray ()>
#          array(51249.29020441)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          25: <xarray.DataArray ()>
#          array(124382.69943791)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          26: <xarray.DataArray ()>
#          array(96544.32581268)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          28: <xarray.DataArray ()>
#          array(40932.78188378)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          29: <xarray.DataArray ()>
#          array(110931.92699965)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          30: <xarray.DataArray ()>
#          array(124414.8779346)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          31: <xarray.DataArray ()>
#          array(66301.61848979)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          32: <xarray.DataArray ()>
#          array(98361.33230909)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          33: <xarray.DataArray ()>
#          array(154885.78158352)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          34: <xarray.DataArray ()>
#          array(137598.56531973)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          35: <xarray.DataArray ()>
#          array(53690.59223849)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          39: <xarray.DataArray ()>
#          array(134453.11489842)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          40: <xarray.DataArray ()>
#          array(137762.46391559)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          41: <xarray.DataArray ()>
#          array(128952.18917052)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          43: <xarray.DataArray ()>
#          array(132489.73134675)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          46: <xarray.DataArray ()>
#          array(142968.22311589)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          47: <xarray.DataArray ()>
#          array(143682.04708042)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          48: <xarray.DataArray ()>
#          array(121957.5390929)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          49: <xarray.DataArray ()>
#          array(108399.71648505)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          50: <xarray.DataArray ()>
#          array(103977.52879156)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          51: <xarray.DataArray ()>
#          array(65021.79484545)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          52: <xarray.DataArray ()>
#          array(142584.20020029)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          53: <xarray.DataArray ()>
#          array(117066.67255476)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          54: <xarray.DataArray ()>
#          array(89977.69946019)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          55: <xarray.DataArray ()>
#          array(146393.27509797)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0})

# %%
EVI_dic={} # dictionary for storing each state's avg index
for i, tif_file in enumerate(EVI_file_list):
    for state_idx in state_idx_list:
        clipped = get_average_vegetation(tif_file, shape_file, state_idx)
        # first time we create keys and values
        # other times we update the dictionary
        if i == 0:
            EVI_dic[state_idx] = clipped
        else:
            EVI_dic[state_idx] += clipped
EVI_dic
# Out:
# {0: Delayed('add-2e42682ddbf16d6ef37462ce2a6bbccb'),
#  1: Delayed('add-88742ae9da6e787df7c7e6ec194b537b'),
#  2: Delayed('add-09a9901c3bce4b2f6e35ed5acf18a928'),
#  3: Delayed('add-1550d0736a6e7766f560ce64870d04ef'),
#  4: Delayed('add-3dcad44208a863bb184454cdd87c185b'),
#  5: Delayed('add-8d2a1b6093bf2577bf9841b6b5f8df97'),
#  6: Delayed('add-6ebeda50352fe9e8535489631f707ff8'),
#  7: Delayed('add-9082935d3de2b4b9bc3d2ea8bd2eacde'),
#  8: Delayed('add-662053bfcea2223864dc42df33def015'),
#  9: Delayed('add-d9b71bc8387888993b56d943f432cef7'),
#  10: Delayed('add-7f73efc00eea7a738482d3027300eaf3'),
#  11: Delayed('add-a3b06a2e52d355a1e00e81d6771f6317'),
#  12: Delayed('add-f1ffc538ed75adbd2dae9111d963d994'),
#  14: Delayed('add-4dc9f0cd34d497b640fd9003775e845c'),
#  15: Delayed('add-f0d1a6c80807349f074cab6f4c9552f2'),
#  16: Delayed('add-9ee97f4a869a22e932c1cfcddcd32240'),
#  17: Delayed('add-92c25c27ea222735a1ef92f739595c1a'),
#  18: Delayed('add-3990a9c10e37a0186e3f221b26290526'),
#  19: Delayed('add-df898139dadb9f4e3d835204aedbd91c'),
#  20: Delayed('add-f51cf8e28f9ae864c6c3f60c97b4e41e'),
#  21: Delayed('add-528996d2a7c9bd309c28c4ce936e7c48'),
#  22: Delayed('add-05682cc4f1ccbe57c72fe193356e7cb9'),
#  23: Delayed('add-a0096e10b3e615c62a4b36297d0255b1'),
#  24: Delayed('add-a340fe64dc5b58393f4fe1e7b5bd6ed5'),
#  25: Delayed('add-1b9729c3e9e25e3c58cf8d8391e2279c'),
#  26: Delayed('add-01fd51da377e1af687406789bebe9fb7'),
#  28: Delayed('add-3ba4111e75922358c31dbe379d9dcf02'),
#  29: Delayed('add-96fea9f3ff6248ea4853ad301dd46b53'),
#  30: Delayed('add-4d21b10651d971e41a8ec256e0c88fe5'),
#  31: Delayed('add-ad40004f05ebebfa3e396e4045fbd9e3'),
#  32: Delayed('add-566a7fd3c06b6e2ecffb8d6419320e72'),
#  33: Delayed('add-0d48ab7b6a17554d13f6152ee8f25da9'),
#  34: Delayed('add-83c1f05a4eb0e6c314578c7f35b84415'),
#  35: Delayed('add-b0f18f81e467f7bc108231a6151f7d21'),
#  39: Delayed('add-fde7db5675d281e1c1a9f9d823573e19'),
#  40: Delayed('add-f8730ebcbda919e025f6a0976f9acd54'),
#  41: Delayed('add-855bebad5c4a65563576a34b5b47c0ce'),
#  43: Delayed('add-cf3794020cbdc817fea0ad8f494ddb9d'),
#  46: Delayed('add-e734f3386cbaefdaea4ca55eb1ff4cd4'),
#  47: Delayed('add-f7e5eae3d9d13bc027d3f918891ff4b4'),
#  48: Delayed('add-cdedb0df8ad554ee671eb9d2c4ea673c'),
#  49: Delayed('add-9d03f501fae8450bcc925a5465f64d8a'),
#  50: Delayed('add-1fb37262bee49b93611804ee886084f9'),
#  51: Delayed('add-8c4544ad33e7897ff1f958bd73e471d2'),
#  52: Delayed('add-a0bcd2e9b01793503f2e39df1c2504a1'),
#  53: Delayed('add-d905f9964d7baae4eed130ea30d65dca'),
#  54: Delayed('add-c732b24b2d5a9b2338caf8d800d96a74'),
#  55: Delayed('add-31792ba808135d1df8a0906bed9106a6')}

# %%
# compute all the values in EVI_dic and update the dictionary
EVI_dic = {k: v.compute() for k, v in EVI_dic.items()}
EVI_dic
# Out:
# Counter({0: <xarray.DataArray ()>
#          array(87154.05748272)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          1: <xarray.DataArray ()>
#          array(86581.12164828)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          2: <xarray.DataArray ()>
#          array(66138.50788721)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          3: <xarray.DataArray ()>
#          array(88907.74063775)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          4: <xarray.DataArray ()>
#          array(86548.04387523)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          5: <xarray.DataArray ()>
#          array(81485.85106271)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          6: <xarray.DataArray ()>
#          array(68628.80720701)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          7: <xarray.DataArray ()>
#          array(81482.56322143)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          8: <xarray.DataArray ()>
#          array(42659.18884239)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          9: <xarray.DataArray ()>
#          array(80933.84184403)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          10: <xarray.DataArray ()>
#          array(54496.42194162)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          11: <xarray.DataArray ()>
#          array(59904.73340403)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          12: <xarray.DataArray ()>
#          array(33335.91301122)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          14: <xarray.DataArray ()>
#          array(47185.12647779)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          15: <xarray.DataArray ()>
#          array(57622.2695836)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          16: <xarray.DataArray ()>
#          array(46547.80091041)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          17: <xarray.DataArray ()>
#          array(90926.25451864)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          18: <xarray.DataArray ()>
#          array(86096.72367421)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          19: <xarray.DataArray ()>
#          array(82672.88892353)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          20: <xarray.DataArray ()>
#          array(80949.56820703)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          21: <xarray.DataArray ()>
#          array(39008.41468123)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          22: <xarray.DataArray ()>
#          array(30693.51137214)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          23: <xarray.DataArray ()>
#          array(88682.96506826)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          24: <xarray.DataArray ()>
#          array(29576.69926074)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          25: <xarray.DataArray ()>
#          array(77051.976866)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          26: <xarray.DataArray ()>
#          array(59803.65739426)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          28: <xarray.DataArray ()>
#          array(24604.20830894)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          29: <xarray.DataArray ()>
#          array(70716.06413481)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          30: <xarray.DataArray ()>
#          array(79324.75071188)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          31: <xarray.DataArray ()>
#          array(36087.02044632)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          32: <xarray.DataArray ()>
#          array(64319.56350511)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          33: <xarray.DataArray ()>
#          array(85109.8368597)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          34: <xarray.DataArray ()>
#          array(83370.67331699)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          35: <xarray.DataArray ()>
#          array(30984.01447681)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          39: <xarray.DataArray ()>
#          array(75980.40782416)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          40: <xarray.DataArray ()>
#          array(81801.76150059)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          41: <xarray.DataArray ()>
#          array(78257.63477151)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          43: <xarray.DataArray ()>
#          array(80988.26072601)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          46: <xarray.DataArray ()>
#          array(80763.68783514)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          47: <xarray.DataArray ()>
#          array(88213.38140506)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          48: <xarray.DataArray ()>
#          array(76844.31583963)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          49: <xarray.DataArray ()>
#          array(67471.84131131)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          50: <xarray.DataArray ()>
#          array(52994.12283416)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          51: <xarray.DataArray ()>
#          array(40378.36690613)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          52: <xarray.DataArray ()>
#          array(81212.57840677)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          53: <xarray.DataArray ()>
#          array(74968.02729048)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          54: <xarray.DataArray ()>
#          array(54861.12852711)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0,
#          55: <xarray.DataArray ()>
#          array(85095.79725343)
#          Coordinates:
#              band         int64 1
#              spatial_ref  int64 0})

# %%
# save the indexes
import pickle
with open('NDVI.pickle', 'wb') as outputfile:
    pickle.dump(NDVI_dic, outputfile)

with open('NDVI.pickle', 'rb') as inputfile:
    print(pickle.load(inputfile))

with open('EVI.pickle', 'wb') as outputfile:
    pickle.dump(EVI_dic, outputfile)

with open('EVI.pickle', 'rb') as inputfile:
    print(pickle.load(inputfile))
# Out:
# Counter({17: <xarray.DataArray ()>
# array(90926.25451864)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 3: <xarray.DataArray ()>
# array(88907.74063775)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 23: <xarray.DataArray ()>
# array(88682.96506826)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 47: <xarray.DataArray ()>
# array(88213.38140506)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 0: <xarray.DataArray ()>
# array(87154.05748272)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 1: <xarray.DataArray ()>
# array(86581.12164828)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 4: <xarray.DataArray ()>
# array(86548.04387523)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 18: <xarray.DataArray ()>
# array(86096.72367421)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 33: <xarray.DataArray ()>
# array(85109.8368597)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 55: <xarray.DataArray ()>
# array(85095.79725343)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 34: <xarray.DataArray ()>
# array(83370.67331699)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 19: <xarray.DataArray ()>
# array(82672.88892353)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 40: <xarray.DataArray ()>
# array(81801.76150059)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 5: <xarray.DataArray ()>
# array(81485.85106271)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 7: <xarray.DataArray ()>
# array(81482.56322143)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 52: <xarray.DataArray ()>
# array(81212.57840677)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 43: <xarray.DataArray ()>
# array(80988.26072601)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 20: <xarray.DataArray ()>
# array(80949.56820703)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 9: <xarray.DataArray ()>
# array(80933.84184403)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 46: <xarray.DataArray ()>
# array(80763.68783514)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 30: <xarray.DataArray ()>
# array(79324.75071188)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 41: <xarray.DataArray ()>
# array(78257.63477151)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 25: <xarray.DataArray ()>
# array(77051.976866)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 48: <xarray.DataArray ()>
# array(76844.31583963)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 39: <xarray.DataArray ()>
# array(75980.40782416)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 53: <xarray.DataArray ()>
# array(74968.02729048)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 29: <xarray.DataArray ()>
# array(70716.06413481)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 6: <xarray.DataArray ()>
# array(68628.80720701)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 49: <xarray.DataArray ()>
# array(67471.84131131)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 2: <xarray.DataArray ()>
# array(66138.50788721)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 32: <xarray.DataArray ()>
# array(64319.56350511)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 11: <xarray.DataArray ()>
# array(59904.73340403)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 26: <xarray.DataArray ()>
# array(59803.65739426)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 15: <xarray.DataArray ()>
# array(57622.2695836)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 54: <xarray.DataArray ()>
# array(54861.12852711)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 10: <xarray.DataArray ()>
# array(54496.42194162)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 50: <xarray.DataArray ()>
# array(52994.12283416)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 14: <xarray.DataArray ()>
# array(47185.12647779)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 16: <xarray.DataArray ()>
# array(46547.80091041)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 8: <xarray.DataArray ()>
# array(42659.18884239)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 51: <xarray.DataArray ()>
# array(40378.36690613)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 21: <xarray.DataArray ()>
# array(39008.41468123)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 31: <xarray.DataArray ()>
# array(36087.02044632)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 12: <xarray.DataArray ()>
# array(33335.91301122)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 35: <xarray.DataArray ()>
# array(30984.01447681)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 22: <xarray.DataArray ()>
# array(30693.51137214)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 24: <xarray.DataArray ()>
# array(29576.69926074)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0, 28: <xarray.DataArray ()>
# array(24604.20830894)
# Coordinates:
#     band         int64 1
#     spatial_ref  int64 0})

# %%
# convert indexes dictionary into list for adding to dataframe, also do average here
NDVI_list = [i[1].values.item(0)/23 for i in list(NDVI_dic.items())]
EVI_list = [i[1].values.item(0)/23 for i in list(EVI_dic.items())]

# %%
NDVI_list
# Out:
# [6712.272121859755,
#  6608.098543052684,
#  4870.779220196754,
#  6633.109402547956,
#  6308.458951800929,
#  6340.529100188768,
#  4875.348258060799,
#  6225.011381415092,
#  3420.6138391513155,
#  6295.864122423586,
#  3732.586165090251,
#  4951.431141213172,
#  2478.390199148947,
#  3393.9714621308117,
#  4248.459263274486,
#  3824.7183559561126,
#  7010.7224828296075,
#  6752.751685297581,
#  5924.2900831230745,
#  5699.448140817931,
#  2992.0327143919417,
#  2230.3446075707884,
#  6474.724662254448,
#  2228.2300088872544,
#  5407.943453822171,
#  4197.5793831600195,
#  1779.6861688601841,
#  4823.127260854282,
#  5409.342518895755,
#  2882.6790647734747,
#  4276.579665612414,
#  6734.164416674608,
#  5982.546318249176,
#  2334.3735755864654,
#  5845.7876042789785,
#  5989.6723441561535,
#  5606.616920457251,
#  5760.423102032725,
#  6216.009700690811,
#  6247.045525235761,
#  5302.50169969118,
#  4713.031151524126,
#  4520.762121372321,
#  2827.0345584978377,
#  6199.313052186504,
#  5089.855328467723,
#  3912.0738895734867,
#  6364.925004259647]

# %%
EVI_list
# Out:
# [3789.306847074834,
#  3764.3965934032685,
#  2875.5872994441097,
#  3865.553940771869,
#  3762.9584293577013,
#  3542.863089683165,
#  2983.861182913645,
#  3542.7201400620766,
#  1854.7473409734393,
#  3518.862688871018,
#  2369.4096496355296,
#  2604.5536262619585,
#  1449.3875222267905,
#  2051.5272381646673,
#  2505.3160688520343,
#  2023.8174308875048,
#  3953.3154138538716,
#  3743.335811922257,
#  3594.4734314579205,
#  3519.546443784024,
#  1696.0180296188523,
#  1334.5004944407428,
#  3855.781089924462,
#  1285.9434461190333,
#  3350.0859506955953,
#  2600.1590171419275,
#  1069.7481873453048,
#  3074.611484122383,
#  3448.90220486455,
#  1569.000888970618,
#  2796.502761091818,
#  3700.4276895523312,
#  3624.8118833471813,
#  1347.1310642089527,
#  3303.4959923548613,
#  3556.598326112741,
#  3402.5058596310782,
#  3521.228727217953,
#  3511.4646884843014,
#  3835.3644089156574,
#  3341.057210418843,
#  2933.558317882911,
#  2304.092297137345,
#  1755.5811698317905,
#  3530.9816698596755,
#  3259.479447412369,
#  2385.2664577004452,
#  3699.8172718881933]

# %% [markdown]
# ## Gather physical and mental data

# %%
# read in physical and mental score
import pandas as pd
physical_score = pd.read_csv('physical_score.csv', index_col=0)
mental_score = pd.read_csv('mental_score.csv', index_col=0)

# %%
physical_score['NDVI'] = NDVI_list
physical_score['EVI'] = EVI_list
mental_score['NDVI'] = NDVI_list
mental_score['EVI'] = EVI_list

# %%
physical_score
# Out:
#    State    Sum         NDVI          EVI
# 0     MS  590.1  6712.272122  3789.306847
# 1     NC  455.4  6608.098543  3764.396593
# 2     OK  577.1  4870.779220  2875.587299
# 3     VA  420.8  6633.109403  3865.553941
# 4     WV  546.0  6308.458952  3762.958429
# 5     LA  540.1  6340.529100  3542.863090
# 6     MI  496.4  4875.348258  2983.861183
# 7     MA  367.6  6225.011381  3542.720140
# 8     ID  443.2  3420.613839  1854.747341
# 9     FL  400.4  6295.864122  3518.862689
# 10    NE  428.8  3732.586165  2369.409650
# 11    WA  414.9  4951.431141  2604.553626
# 12    NM  407.9  2478.390199  1449.387522
# 13    SD  438.4  3393.971462  2051.527238
# 14    TX  452.4  4248.459263  2505.316069
# 15    CA  401.1  3824.718356  2023.817431
# 16    AL  568.9  7010.722483  3953.315414
# 17    GA  485.9  6752.751685  3743.335812
# 18    PA  444.0  5924.290083  3594.473431
# 19    MO  496.1  5699.448141  3519.546444
# 20    CO  376.3  2992.032714  1696.018030
# 21    UT  401.5  2230.344608  1334.500494
# 22    TN  539.4  6474.724662  3855.781090
# 23    WY  447.1  2228.230009  1285.943446
# 24    NY  395.1  5407.943454  3350.085951
# 25    KS  447.8  4197.579383  2600.159017
# 26    NV  465.9  1779.686169  1069.748187
# 27    IL  434.8  4823.127261  3074.611484
# 28    VT  431.5  5409.342519  3448.902205
# 29    MT  421.8  2882.679065  1569.000889
# 30    IA  450.8  4276.579666  2796.502761
# 31    SC  484.7  6734.164417  3700.427690
# 32    NH  406.5  5982.546318  3624.811883
# 33    AZ  395.9  2334.373576  1347.131064
# 34    NJ  401.4  5845.787604  3303.495992
# 35    MD  418.5  5989.672344  3556.598326
# 36    ME  440.2  5606.616920  3402.505860
# 37    DE  456.8  5760.423102  3521.228727
# 38    RI  416.3  6216.009701  3511.464688
# 39    KY  543.9  6247.045525  3835.364409
# 40    OH  508.2  5302.501700  3341.057210
# 41    WI  432.4  4713.031152  2933.558318
# 42    OR  411.1  4520.762121  2304.092297
# 43    ND  412.1  2827.034558  1755.581170
# 44    AR  560.6  6199.313052  3530.981670
# 45    IN  502.3  5089.855328  3259.479447
# 46    MN  380.8  3912.073890  2385.266458
# 47    CT  365.4  6364.925004  3699.817272

# %%
mental_score
# Out:
#    State      Sum         NDVI          EVI
# 0     MS   4018.8  6712.272122  3789.306847
# 1     NC  28536.7  6608.098543  3764.396593
# 2     OK   8683.0  4870.779220  2875.587299
# 3     VA  17214.0  6633.109403  3865.553941
# 4     WV  11564.2  6308.458952  3762.958429
# 5     LA  14226.1  6340.529100  3542.863090
# 6     MI  32346.0  4875.348258  2983.861183
# 7     MA  28045.9  6225.011381  3542.720140
# 8     ID   2833.9  3420.613839  1854.747341
# 9     FL  62372.2  6295.864122  3518.862689
# 10    NE   1886.4  3732.586165  2369.409650
# 11    WA  14219.9  4951.431141  2604.553626
# 12    NM   6138.0  2478.390199  1449.387522
# 13    SD    763.3  3393.971462  2051.527238
# 14    TX  36548.7  4248.459263  2505.316069
# 15    CA  65328.9  3824.718356  2023.817431
# 16    AL   9419.5  7010.722483  3953.315414
# 17    GA  17446.6  6752.751685  3743.335812
# 18    PA  58828.9  5924.290083  3594.473431
# 19    MO  18184.5  5699.448141  3519.546444
# 20    CO  12469.9  2992.032714  1696.018030
# 21    UT   8032.2  2230.344608  1334.500494
# 22    TN  22644.6  6474.724662  3855.781090
# 23    WY    800.2  2228.230009  1285.943446
# 24    NY  28983.3  5407.943454  3350.085951
# 25    KS   4084.3  4197.579383  2600.159017
# 26    NV   9011.8  1779.686169  1069.748187
# 27    IL  33731.3  4823.127261  3074.611484
# 28    VT   1644.8  5409.342519  3448.902205
# 29    MT   1326.9  2882.679065  1569.000889
# 30    IA   3708.5  4276.579666  2796.502761
# 31    SC  12663.4  6734.164417  3700.427690
# 32    NH   5547.4  5982.546318  3624.811883
# 33    AZ  20151.2  2334.373576  1347.131064
# 34    NJ  33337.3  5845.787604  3303.495992
# 35    MD  28937.2  5989.672344  3556.598326
# 36    ME   4735.5  5606.616920  3402.505860
# 37    DE   4485.4  5760.423102  3521.228727
# 38    RI   3962.5  6216.009701  3511.464688
# 39    KY  16927.5  6247.045525  3835.364409
# 40    OH  51675.3  5302.501700  3341.057210
# 41    WI  13755.8  4713.031152  2933.558318
# 42    OR   6705.0  4520.762121  2304.092297
# 43    ND    921.2  2827.034558  1755.581170
# 44    AR   5341.3  6199.313052  3530.981670
# 45    IN  20352.0  5089.855328  3259.479447
# 46    MN   8165.1  3912.073890  2385.266458
# 47    CT  12869.6  6364.925004  3699.817272

# %% [markdown]
# ## Modeling

# %%
import statsmodels.api as sm

# %%
# formula = 'vegetation access ~ physical health compound score'

X_physical = physical_score[['NDVI', 'EVI']]
y_physical = physical_score['Sum']
model_physical = sm.OLS(y_physical, X_physical)
reg_physical = model_physical.fit()
print(reg_physical.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    Sum   R-squared (uncentered):                   0.934
# Model:                            OLS   Adj. R-squared (uncentered):              0.932
# Method:                 Least Squares   F-statistic:                              328.0
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):                    5.98e-28
# Time:                        18:44:04   Log-Likelihood:                         -296.61
# No. Observations:                  48   AIC:                                      597.2
# Df Residuals:                      46   BIC:                                      601.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# NDVI           0.0105      0.064      0.166      0.869      -0.117       0.138
# EVI            0.1269      0.108      1.174      0.247      -0.091       0.344
# ==============================================================================
# Omnibus:                        1.946   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.378   Jarque-Bera (JB):                1.865
# Skew:                           0.412   Prob(JB):                        0.394
# Kurtosis:                       2.497   Cond. No.                         43.7
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# formula = 'vegetation access ~ mental health compound score'

X_mental = mental_score[['NDVI', 'EVI']]
y_mental = mental_score['Sum']
model_mental = sm.OLS(y_mental, X_mental)
reg_mental = model_mental.fit()
print(reg_mental.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    Sum   R-squared (uncentered):                   0.547
# Model:                            OLS   Adj. R-squared (uncentered):              0.527
# Method:                 Least Squares   F-statistic:                              27.74
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):                    1.25e-08
# Time:                        18:44:10   Log-Likelihood:                         -532.31
# No. Observations:                  48   AIC:                                      1069.
# Df Residuals:                      46   BIC:                                      1072.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# NDVI           3.2710      8.622      0.379      0.706     -14.085      20.627
# EVI            0.1490     14.667      0.010      0.992     -29.374      29.672
# ==============================================================================
# Omnibus:                       19.778   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.364
# Skew:                           1.503   Prob(JB):                     3.11e-06
# Kurtosis:                       4.909   Cond. No.                         43.7
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
